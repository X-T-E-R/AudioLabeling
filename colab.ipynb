# %% [markdown]
# <a href="https://colab.research.google.com/github/X-T-E-R/AudioLabeling/blob/main/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 项目、环境有关 Env

# %%
# @title Clone or Update the repository 克隆或更新存储库
# %cd /content/
# !git clone https://github.com/X-T-E-R/AudioLabeling.git 

# Make sure to pull the latest changes from the repository
# %cd /content/AudioLabeling
# !git stash
# !git pull https://github.com/X-T-E-R/AudioLabeling.git

# %%
# @title 安装依赖项 Install dependencies 
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# %pip install -r requirements.txt

# %% [markdown]
# 数据准备

# %% [markdown]
# 说明：
# 数据准备需要一到几个人声长音频，最好放置在同一个文件夹里面
# 你可以从视频中扒拉下来、从网站上扒拉下来或者自己录，但请注意版权问题。
# （另外特别声明：本工具仅是一个机械的处理音频的工具，不能对任何数据相关的版权做保证、如您不同意这一点，请立即放弃使用）
#
# 本来不需要做处理，但是因为本项目的人声分离、音频降噪还没做好
# 因此请手动分离好人声再上传
#
# 你可以直接用在线服务比如 https://mvsep.com/zh （免费）来分离。

# %%
# @title （可选）设置路径或手动上传 Set path or manually upload
# %cd /content/AudioLabeling
import os

folder_name = 'test_audio' # @param {type: "string"}
source_path = os.path.join("Input/audios", folder_name)
os.makedirs(source_path, exist_ok=True)

# 然后手动上传音频文件到 比如 "Input/audios/test/" 中
# 或者使用下一个代码块自动下载zip包

# Then manually upload the audio files to e.g. "Input/audios/test/"
# Or use the next code block to automatically download a zip file
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/AudioLabeling'
# e:\AItools\AudioLabeling

# %%
#@title (可选)下载音频压缩包 Download audio zip file
# %cd /content/AudioLabeling


import requests
import os
import urllib.parse



# copy the link from the download button on the model page
hf_link = 'https://huggingface.co/datasets/XTer123/AudioLabelingTestDataset/resolve/main/test_audio.zip?download=true' #@param {type: "string"}


# get the name of the character folder, or you can set it manually
folder_name = urllib.parse.unquote(os.path.basename(hf_link).rsplit('.', 1)[0])

print(f'Downloading {folder_name}...')

source_path = os.path.join('Input/audios', folder_name)
os.makedirs(source_path, exist_ok=True)

zip_file_path = os.path.join(source_path, 'file.zip')

# download the zip file
response = requests.get(hf_link)
with open(zip_file_path, 'wb') as file:
    file.write(response.content)

print(f'{folder_name} downloaded successfully!')
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/AudioLabeling'
# e:\AItools\AudioLabeling
# Downloading test_audio...
# test_audio downloaded successfully!

# %%
# @title （可选）解压zip文件 extract zip file
# %cd /content/AudioLabeling
# extract the zip file
import zipfile

assert source_path, 'source_path is not defined. Please define the source_path variable.'
assert folder_name, 'folder_name is not defined. Please define the folder_name variable.'

try:
    print(f'Extracting {zip_file_path}...')
except:
    zip_file_path = "" #@param {type: "string"}
    print(f'Extracting {zip_file_path}...')
    
def get_decoder(file_name: str):
    try:
        return file_name.encode('cp437').decode('gbk')
    except:
        return file_name

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    for file_info in zip_ref.infolist():
        # 解码并重新编码文件名
        encoded_file_name = get_decoder(file_info.filename)
        new_path = os.path.join(source_path, encoded_file_name)
        source = zip_ref.open(file_info.filename)
        # 判断f是否是目录，目录的结尾是'/'或'\'
        if encoded_file_name[-1] not in ['\\','/']:
            with open(new_path,'wb') as file:
                file.write(zip_ref.read(file_info.filename))
                file.close()
        else:
            os.makedirs(new_path, exist_ok=True)
print(f'{folder_name} extracted successfully!')
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/AudioLabeling'
# e:\AItools\AudioLabeling
# Extracting Input/audios\test_audio\file.zip...
# test_audio extracted successfully!

# %% [markdown]
# 前置处理 PreProcessing

# %%
# @title 分离人声 Separate Vocals

# 这个部分还没有写好，请使用 uvr 5 或 MVSEP-MDX23 手动分离
# This part is not ready yet, please use uvr 5 or MVSEP-MDX23 to separate manually

# %% [markdown]
# 生成字幕、切分音频 SRT and Slice

# %% [markdown]
# 说明：
#
# 你可以直接跳过生成srt的步骤，比如事前用剪映、Whisper生成好srt
#
# 然后将srt与音频文件同名上传即可
#
# 如果没有gpu资源，生成会相当慢速，因此还是建议 在有GPU资源的时候运行代码（应该会每天刷新） / 事前用剪映生成好 / 在本地运行代码

# %%
# @title 生成srt字幕 Generate srt subtitles
# %cd /content/AudioLabeling
import os

try:
    print(f"source_path: {source_path}")
except:
    source_path = "Input/audios/test/" # @param {type:"string"}
    
os.makedirs(source_path, exist_ok=True)

from tools.my_utils import scan_audios_walk

audio_list = []
if os.path.isdir(source_path):
    audio_list = scan_audios_walk(source_path)
    audio_list = [os.path.join(source_path, audio) for audio in audio_list]
else:
    audio_list.append(source_path)
    
from src.srt_generator.audio2srt import Audio2Srt

models_path = 'models/iic' # 设定模型路径，留空或路径不存在则 modelscope 会自动下载模型 @param {type:"string"}


with Audio2Srt(models_path=models_path) as a2s:
    for audio_path in audio_list:
        srt_path = audio_path.rsplit('.', 1)[0] + '.srt'
        srt_content = a2s.generate_srt(audio_path)
        try:
            with open(srt_path, 'w') as f:
                f.write(srt_content)
            print(f"生成字幕文件：{srt_path}")
        except:
            print(f"生成字幕文件失败：{srt_path}")
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/AudioLabeling'
# e:\AItools\AudioLabeling
# source_path: Input/audios\test_audio
# Please install torch_complex firstly
# ckpt: models/iic\paraformer-zh\model.pt
# ckpt: models/iic\fsmn-vad\model.pt
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\xxoy1\AppData\Local\Temp\jieba.cache
# DEBUG:jieba:Loading model from cache C:\Users\xxoy1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.327 seconds.
# DEBUG:jieba:Loading model cost 0.327 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
# @title 切分音频 Split Audio
# %cd /content/AudioLabeling
import os
import shutil


try:
    print(f"folder_name: {folder_name}")
except:
    folder_name = "test" # @param {type:"string"}
source_path = os.path.join("Input/audios", folder_name) # @param {type:"string"}
os.makedirs(source_path, exist_ok=True)

folder_name = os.path.basename(source_path)
output_path = f"Output/sliced_audio/{folder_name}/" # @param {type:"string"}

os.makedirs(output_path, exist_ok=True)

print(f"Remove old files in {output_path}")
shutil.rmtree(output_path, ignore_errors=True)

from tools.my_utils import scan_audios_walk, scan_ext_walk

# scan srt files and audio files
print(f"scan srt files and audio files in {source_path}")
items = []

if os.path.isdir(source_path):
    srt_list = scan_ext_walk(source_path, '.srt')
    audio_list = scan_audios_walk(source_path)
else:   
    audio_list = [source_path]
    source_path = os.path.dirname(source_path)
    srt_list = scan_ext_walk(source_path, '.srt')

print(f"audio_list: {audio_list}")
print(f"srt_list: {srt_list}")
for audio_file in audio_list:
    audio_file_name = os.path.basename(audio_file).rsplit('.', 1)[0]
    for srt_file in srt_list:
        if audio_file_name in srt_file:
            items.append((audio_file, srt_file))
            print(f"找到配对的音频文件：{audio_file} 和字幕文件：{srt_file}")
            break

from src.srt_slicer.srt_utils import merge_subtitles_with_lib, slice_audio_with_lib, parse_srt_with_lib, generate_srt_with_lib, filter_subtitles

# srt合并设置
merge_zero_interval = True # @param {type:"boolean"} 
short_interval = 0.05 # @param {type:"number"}
max_interval = 0.8 # @param {type:"number"}
max_text_length = 100 # @param {type:"number"}
add_period = True # @param {type:"boolean"}

min_text_len = 5 # @param {type:"number"}
language = 'ZH' # @param {type:"string"}

merge_folder = False # @param {type:"boolean"}

min_audio_duration = 2 # @param {type:"number"}
max_audio_duration = 300 # @param {type:"number"}

save_paths = []
for index, item in enumerate(items):
    audio_file, srt_file = item
    print(f"开始切分音频文件：{audio_file} 从字幕文件：{srt_file}")
    save_path = os.path.join(output_path, f"{index}_{os.path.basename(srt_file).rsplit('.', 1)[0]}")
    save_paths.append(save_path)
    audio_file_full_path = os.path.join(source_path, audio_file)
    srt_file_full_path = os.path.join(source_path, srt_file)
    
    try:
        with open(srt_file_full_path, 'r') as f:
            srt_content = f.read()
        subtitles = parse_srt_with_lib(srt_content)
        merged_subtitles = merge_subtitles_with_lib(subtitles, short_interval, max_interval, max_text_length, add_period, merge_zero_interval)
        merged_subtitles = filter_subtitles(merged_subtitles, min_text_len)
        print(generate_srt_with_lib(merged_subtitles))
    except Exception as e:
        print(f"打开字幕文件失败：{srt_file_full_path}")
        raise e
    print(f"合并字幕完成，开始切分音频")
    
    try:
        slice_audio_with_lib(audio_file_full_path, save_folder=save_path, format="wav", subtitles=merged_subtitles, language=language, min_audio_duration=min_audio_duration, max_audio_duration=max_audio_duration)
    except Exception as e:
        print(f"切分音频文件失败：{audio_file_full_path}")
        raise e
    


if merge_folder and len(save_paths) > 1:
    print(f"开始合并文件夹")
    from src.list_merger.list_utils import merge_list_folders

    first_folder = save_paths[0]
    first_list_file = os.path.join(first_folder, 'datamapping.list')
    for i in range(1, len(save_paths)):
        second_folder = save_paths[i]
        second_list_file = os.path.join(second_folder, 'datamapping.list')
        merge_list_folders(first_list_file, second_list_file, None, first_folder, second_folder)
        
    print(f"合并文件夹完成，开始清理")
    output_path = output_path[:-1] if output_path.endswith('/') else output_path
    tmp_path = output_path + "_tmp"
    shutil.rmtree(tmp_path, ignore_errors=True)
    shutil.move(first_folder, tmp_path)
    shutil.rmtree(output_path, ignore_errors=True)
    shutil.move(tmp_path, output_path)
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/AudioLabeling'
# e:\AItools\AudioLabeling
# folder_name: test_audio
# Remove old files in Output/sliced_audio/test_audio/
# scan srt files and audio files in Input/audios\test_audio
# audio_list: ['audio1.MP3', 'audio2.MP3', 'audio3.MP3']
# srt_list: ['audio1.srt', 'audio2.srt', 'audio3.srt']
# 找到配对的音频文件：audio1.MP3 和字幕文件：audio1.srt
# 找到配对的音频文件：audio2.MP3 和字幕文件：audio2.srt
# 找到配对的音频文件：audio3.MP3 和字幕文件：audio3.srt
# 开始切分音频文件：audio1.MP3 从字幕文件：audio1.srt
# 1
# 00:00:00,270 --> 00:00:08,150
# 然后其实这个也是非常正常的现象啊，就很多人哪怕没有牡丹，可能在感情中呢也不算是有很多顺利的存在。
#
# 2
# 00:00:08,490 --> 00:00:12,750
# 可能就是像我啊都没谈多久就分了，当然也没有几个。
#
# 3
# 00:00:13,330 --> 00:00:23,530
# 接下来呢嗯开始我进行了一些分类合并啊，第一个部分呢他说的是关于打游戏的。
#
# 4
# 00:00:23,930 --> 00:00:30,410
# 那么其实打游戏，我先说我自己的故事吧，那个时候高中毕业，我的初恋是我的高中同学。
#
# 5
# 00:00:30,430 --> 00:00:35,630
# 那个时候呢我们打一款新的 OL游戏，听起来好久远的东西啊。
#
# 6
# 00:00:35,650 --> 00:00:42,970
# 嗯，那个时候我完全没有接触过游戏，我也不知道任何的东西，所以呢我就先从辅助位开始打起的，我记得非常清楚。
#
# 7
# 00:00:42,970 --> 00:00:53,890
# 那个时候我打的是一个奶妈的职业，跟我们班的一群男生，他们经常开团打副本的时候就叫我一起，其实都是一些小心思呢，能够靠他更近一点。
#
# 8
# 00:00:53,890 --> 00:00:56,145
# 那个时候其实两个人还没有确认关系，
#
# 9
# 00:00:57,340 --> 00:00:58,400
# 我们来看留言。
#
# 10
# 00:00:58,480 --> 00:01:07,860
# 首先是 FUTABU芜湖，他说初三的时候过年，他找我说 TJ，我说停机别找我，我王者都没钱买皮肤。
#
# 11
# 00:01:08,180 --> 00:01:13,860
# 后来他把字打完整了，说是痛经，他只是随便的口头安慰了几句就没有了。
#
# 12
# 00:01:13,860 --> 00:01:16,580
# 现在分开想了想，好像也挺可惜的。
#
# 13
# 00:01:17,080 --> 00:01:22,780
# 我当时可能因为看到了王者把他跪在游戏里面吧，我觉得也不算离谱吧。
#
# 14
# 00:01:24,280 --> 00:01:31,420
# 所有的男生啊在这所有的年龄段都会存在，说王者嗯，就或者说泛指游戏吧。
#
# 15
# 00:01:31,420 --> 00:01:34,340
# 游戏和女朋友或者说喜欢过的人，哪个更重要？
#
# 16
# 00:01:34,980 --> 00:01:38,900
# 女生会希望通过这种方式来确认她在你心中的地位。
#
# 17
# 00:01:39,200 --> 00:01:47,780
# 但是如果你这样的话，无可厚非啊，哪怕我作为一个女生，我有的时候我打王者，要是有人在我打王者的时候找，我会非常生气，我完全不会回复她。
#
# 18
# 00:01:48,000 --> 00:01:50,895
# 所以这个东西呢也说不好，这个不算特别离谱啊。
#
# 19
# 00:01:52,020 --> 00:01:55,950
# 嗯，可惜嗯也没什么可惜的吧。
#
# 20
# 00:01:55,950 --> 00:01:59,950
# 毕竟高中的时候你就是从心所欲的。
#
# 21
# 00:02:00,170 --> 00:02:09,670
# 你当时能做出来的选择，哪怕是你恢复到那个年纪，你一旦回到了那个年少青春年少轻狂的状态，你还是会做出一样的选择。
#
# 22
# 00:02:09,930 --> 00:02:13,115
# 所以所有的事情呢可以惋惜，但不要后悔啊。
#
# 23
# 00:02:14,080 --> 00:02:16,480
# 第二条下一条是带上帝之手。
#
# 24
# 00:02:16,480 --> 00:02:23,600
# 他说初中在网吧打联盟认识的初恋，他玩软辅的，我玩上单啊，我没有玩过联盟，他说的我不太知道啊。
#
# 25
# 00:02:23,600 --> 00:02:29,040
# 绝活杰斯高一逃课和他打排位，当时打联盟贼自信，可他一口气打到钻石。
#
# 26
# 00:02:29,480 --> 00:02:37,775
# 嗯，我知道的是好像联盟打上钻石还挺难的，不像王者后面分班，她读文学艺术去了，找了一个玩 AD的做男友，
#
# 27
# 00:02:38,690 --> 00:02:47,770
# 后面这段就属于是情感升华了啊，这个情感暴击我到现在都还不会玩 AD，也再没有上过钻石，我和我的杰斯一起入了土。
#
# 28
# 00:02:48,290 --> 00:02:53,590
# 这个嗯其实不算离谱啦，也只是更多的牵涉到遗憾的事情。
#
# 29
# 00:02:53,590 --> 00:03:05,170
# 其实他并不是真的就是缺 AD，是说在他的那段感情经历里面，你不是那个人而已啊，第二条呢是关于吃的的啊呃这个。
#
#
# 合并字幕完成，开始切分音频
# Slice character_001.wav from 0.17 to 8.200000000000001
# Slice character_002.wav from 8.39 to 12.8
# Slice character_003.wav from 13.23 to 23.580000000000002
# Slice character_004.wav from 23.83 to 30.42
# Slice character_005.wav from 30.42 to 35.64
# Slice character_006.wav from 35.64 to 42.97
# Slice character_007.wav from 42.97 to 53.89
# Slice character_010.wav from 58.44 to 67.91
# Slice character_011.wav from 68.08000000000001 to 73.86
# Slice character_013.wav from 76.98 to 82.83
# Slice character_014.wav from 84.18 to 91.42
# Slice character_015.wav from 91.42 to 94.39
# Slice character_016.wav from 94.88000000000001 to 98.95
# Slice character_017.wav from 99.10000000000001 to 107.83
# Slice character_018.wav from 107.9 to 110.945
# Slice character_019.wav from 111.92 to 115.95
# Slice character_020.wav from 115.95 to 120.0
# Slice character_021.wav from 120.07000000000001 to 129.72
# Slice character_022.wav from 129.83 to 133.16500000000002
# Slice character_024.wav from 136.48 to 143.6
# Slice character_025.wav from 143.6 to 149.09
# Slice character_026.wav from 149.38 to 157.82500000000002
# Slice character_027.wav from 158.59 to 167.82000000000002
# Slice character_028.wav from 168.19 to 173.59
# Slice character_029.wav from 173.59 to 185.18194081632652
# 开始切分音频文件：audio2.MP3 从字幕文件：audio2.srt
# 1
# 00:00:00,050 --> 00:00:02,510
# 酸酸的，但是绝对不会觉得苦啊。
#
# 2
# 00:00:02,510 --> 00:00:16,330
# 接下来呢是天语素，他说没有太离谱的，只记得当时他姨妈家感冒，说想喝粥，我就买了锅米、红枣之类的，天天熬粥给他喝，后来也经常熬粥给他，只是他说粥没有以前好喝了，现在想想不好喝。
#
# 3
# 00:00:16,330 --> 00:00:24,150
# 不是粥的问题，当然不是粥的问题，就像一个人不可能时时刻刻都想喝粥，一个女生不可能时时刻刻都来姨妈。
#
# 4
# 00:00:24,210 --> 00:00:31,285
# 只是说嗯很多感情他可以寄托在某个东西上面，但是他不一定就会那么持久。
#
# 5
# 00:00:32,070 --> 00:00:37,070
# 所以当然不是周的问题，只是说感情淡了，或者说不太合适了。
#
# 6
# 00:00:37,430 --> 00:00:41,750
# 迎面走来的呢，我愿称之为是文艺作品组啊。
#
# 7
# 00:00:42,050 --> 00:00:47,790
# 首先呢信会他说没干过啥离谱的事儿，也就是我和他的故事写成了短篇小说。
#
# 8
# 00:00:48,450 --> 00:00:54,510
# 但这个事情其实我当时也有干过，只不过呢是看你是纪实的。
#
# 9
# 00:00:54,510 --> 00:01:00,910
# 比如说像写日记那样或回忆录之类的，还是说进行了一定的艺术创作，把它变成了短篇小说。
#
# 10
# 00:01:01,270 --> 00:01:05,390
# 这个呢其实更多的是一种记录方式而已。
#
# 11
# 00:01:05,410 --> 00:01:15,180
# 不管是说比如说小小说的话，一定程度上可能就会带有美化，或者说自己补充细节的部分，但都是怀念青春的手段而已啊。
#
# 12
# 00:01:15,480 --> 00:01:17,580
# 嗯也是想想挺文艺的啊。
#
# 13
# 00:01:17,640 --> 00:01:23,500
# 好，喵三三说最离谱的是大概就是过度上头两周时间给他写了一本十万字的书。
#
# 14
# 00:01:23,840 --> 00:01:31,080
# 然后这本书被他前女友偷看了，女友揣测过他的爱情余波未平，甚至有个孩子他很生气，和他分了。
#
# 15
# 00:01:31,180 --> 00:01:35,640
# 我不明白嗯这件事情呢就确实是带了点离谱。
#
# 16
# 00:01:35,800 --> 00:01:41,120
# 你非说的话，嗯，人心是比较难揣度的东西。
#
# 17
# 00:01:41,540 --> 00:01:44,975
# 那如果说他女友看到了这个十万字的书啊，
#
# 18
# 00:01:46,660 --> 00:01:51,955
# 就像是 CP文走进生活舞到正主面前那种感觉吧，
#
# 19
# 00:01:53,120 --> 00:01:54,820
# 怎么听都带点离谱。
#
# 20
# 00:01:54,860 --> 00:01:58,720
# 但是你非说在年轻时候干这种事儿呢也很正常。
#
# 21
# 00:01:59,200 --> 00:02:06,100
# 嗯，如果是我的话，嗯，也只能说那个时候很容易受到外界因素的影响吧。
#
# 22
# 00:02:06,100 --> 00:02:12,500
# 我觉得这个发展走向倒是挺正常的，但这个事情本身就是能发生，就只能说是艺术来源于生活啊。
#
# 23
# 00:02:12,960 --> 00:02:21,000
# 乌西迪西说，分享一下情感故事，中学时候也是诗词兴趣浓厚的时候，喜欢一个人，为了要她的联系方式去找她闺蜜。
#
# 24
# 00:02:21,340 --> 00:02:23,440
# 闺蜜没回复，就是和她表白。
#
# 25
# 00:02:23,440 --> 00:02:29,080
# 转天，她闺蜜找上她，拒绝了闺蜜在学校表白墙，匿名挂，她一气之下删了。
#
# 26
# 00:02:29,080 --> 00:02:33,480
# 当年用诗词记下的故事挺惨的，怎么说呢？
#
# 27
# 00:02:33,560 --> 00:02:39,880
# 嗯，这种事儿我也干过，我基本上所有真心喜欢过的人，联系方式全都没有留，只留了一些。
#
# 28
# 00:02:39,880 --> 00:02:46,380
# 当时觉得哦好好好甜，我一定要保存下来的一些聊天记录之外，没有留下任何其他的东西。
#
# 29
# 00:02:46,380 --> 00:02:53,440
# 但其实你这样想一想，嗯，诗词是无辜的，因为它是一种独属于那个时间的。
#
# 30
# 00:02:53,440 --> 00:03:03,450
# 你去记录自己情感和想法的一个载体，你可以记恨这个人，但是这个东西丢了的话还是挺可惜的。
#
# 31
# 00:03:03,690 --> 00:03:05,645
# 嗯，以上呢就是文学作品组，
#
# 32
# 00:03:06,460 --> 00:03:10,315
# 接下来呢进入的是嗯 happy ending组。
#
# 33
# 00:03:11,080 --> 00:03:14,060
# 首先小发他说为什么大家都是 b一对？
#
# 34
# 00:03:14,120 --> 00:03:24,020
# 就是这个留言里面大部分都是 b一，因为离谱嘛，当然也不是说意味着一定是啊，比如说这一页的两位两位小伙伴就是比较好的。
#
# 35
# 00:03:24,020 --> 00:03:29,320
# 结果小发说，为了他割了大成十三万的 offer，回了老家的要生性国企拿七千。
#
# 36
# 00:03:29,740 --> 00:03:32,440
# 甚至因为这个被列入行业黑名单。
#
# 37
# 00:03:32,940 --> 00:03:36,980
# 他们两个人从初一到现在，恋爱整整十二年，即将英年早婚。
#
# 38
# 00:03:37,040 --> 00:03:40,680
# 感情上还是多为对方考虑，他也为我放弃很多机会。
#
# 39
# 00:03:40,960 --> 00:03:45,780
# 双方家境也可以就是门当户对嘛，以真心换真心与诸位共眠。
#
# 40
# 00:03:46,120 --> 00:03:50,530
# 其实这种情况呢嗯也挺多的。
#
# 41
# 00:03:50,590 --> 00:04:01,190
# 我的是一些同学啊，很多也有很多都结婚了，大部分能走的长远的，就是那种很长时间的感情的，基本上家庭条件都差不了太多。
#
# 42
# 00:04:01,650 --> 00:04:06,950
# 当然这里我不想太牵扯门当户对，这个到底是不是非常必要的一个问题啊？
#
# 43
# 00:04:06,950 --> 00:04:16,770
# 但是他说的这句话以真心换真心，然后不断的去磨合快六同的规划，未来一定是一个向好的状态。
#
# 44
# 00:04:17,130 --> 00:04:19,050
# 祝小发和他的女朋友幸福。
#
# 45
# 00:04:19,590 --> 00:04:31,850
# 嗯，下一条是 lonely cat，他说和女友分分合合快六年了，期间各种蠢事、措施基本都犯过了也经历了来自各方面的反对和阻碍，他们都放弃了很多。
#
# 46
# 00:04:31,870 --> 00:04:38,150
# 但万幸，现在时来运转，两个人都在大城市有了稳定的工作，不断向上牌得到了所有人的肯定。
#
# 47
# 00:04:38,530 --> 00:04:48,975
# 他说，本以为可以无忧无虑，但现实就是车房婚，还有无数个西钱黑洞等着我们这样说，有压力才有动力苦中作乐，希望能挺过去走到最后。
#
# 48
# 00:04:49,460 --> 00:04:55,460
# 首先呢当然是祝福啊，嗯像 lonely cat说的这种情况，就是大部分普通人的情况。
#
# 49
# 00:04:55,900 --> 00:05:02,300
# 而且他比较幸运的一点是，会有一个人有着共同的目标，共同向上向好的往上走。
#
# 50
# 00:05:02,640 --> 00:05:08,880
# 这种情况就是比较幸福的了，嗯，就没有什么离谱的成分在啊就是祝福。
#
# 51
# 00:05:09,060 --> 00:05:15,840
# 毕竟嗯我个人是觉得已经分手了的人呢很难在做朋友。
#
# 52
# 00:05:15,880 --> 00:05:19,740
# 但是我也有一点点不能理解，就是分分合合这种情况。
#
# 53
# 00:05:20,140 --> 00:05:32,325
# 但是呢在人家身上就是有很多人是这样的意，是类似于相爱相杀吧，反正言而总之总而言之，嗯，祝他们两对可以一直幸福下去。
#
# 54
# 00:05:33,290 --> 00:05:36,870
# 然后接下来呢就呃开始进入逐渐离谱的组了啊。
#
# 55
# 00:05:36,910 --> 00:05:46,005
# 首先，第一组莫辞说和女友在一起，前女友突然跑来找我，我一时慌张对女友说，你快回家，我前女友来了。
#
#
# 合并字幕完成，开始切分音频
# Slice character_002.wav from 2.51 to 16.33
# Slice character_003.wav from 16.33 to 24.18
# Slice character_004.wav from 24.18 to 31.335
# Slice character_005.wav from 31.97 to 37.12
# Slice character_006.wav from 37.33 to 41.8
# Slice character_007.wav from 41.949999999999996 to 47.839999999999996
# Slice character_008.wav from 48.35 to 54.51
# Slice character_009.wav from 54.51 to 60.959999999999994
# Slice character_010.wav from 61.17 to 65.4
# Slice character_011.wav from 65.4 to 75.23
# Slice character_013.wav from 77.61 to 83.55
# Slice character_014.wav from 83.74000000000001 to 91.13
# Slice character_015.wav from 91.13 to 95.69
# Slice character_016.wav from 95.72 to 101.17
# Slice character_017.wav from 101.44000000000001 to 105.02499999999999
# Slice character_018.wav from 106.56 to 112.005
# Slice character_020.wav from 114.84 to 118.77
# Slice character_021.wav from 119.10000000000001 to 126.1
# Slice character_022.wav from 126.1 to 132.55
# Slice character_023.wav from 132.86 to 141.05
# Slice character_025.wav from 143.44 to 149.08
# Slice character_026.wav from 149.08 to 153.51999999999998
# Slice character_027.wav from 153.51999999999998 to 159.88
# Slice character_028.wav from 159.88 to 166.38
# Slice character_029.wav from 166.38 to 173.44
# Slice character_030.wav from 173.44 to 183.5
# Slice character_032.wav from 186.36 to 190.365
# Slice character_033.wav from 190.98000000000002 to 194.09
# Slice character_034.wav from 194.09 to 204.02
# Slice character_035.wav from 204.02 to 209.37
# Slice character_037.wav from 212.84 to 217.01
# Slice character_038.wav from 217.01 to 220.73000000000002
# Slice character_039.wav from 220.86 to 225.83
# Slice character_040.wav from 226.02 to 230.56
# Slice character_041.wav from 230.56 to 241.24
# Slice character_042.wav from 241.55 to 246.95
# Slice character_043.wav from 246.95 to 256.82
# Slice character_045.wav from 259.48999999999995 to 271.86
# Slice character_046.wav from 271.86 to 278.2
# Slice character_047.wav from 278.42999999999995 to 289.02500000000003
# Slice character_048.wav from 289.35999999999996 to 295.51
# Slice character_049.wav from 295.79999999999995 to 302.35
# Slice character_050.wav from 302.53999999999996 to 308.93
# Slice character_051.wav from 308.97 to 315.86
# Slice character_052.wav from 315.86 to 319.79
# Slice character_053.wav from 320.03999999999996 to 332.375
# Slice character_054.wav from 333.19 to 336.89
# Slice character_055.wav from 336.89 to 346.055
# 开始切分音频文件：audio3.MP3 从字幕文件：audio3.srt
# 1
# 00:00:00,090 --> 00:00:07,990
# 他甚至想一想嗯，让他的前女友和他女朋友的前男友在一块儿听一听，感受一下，是不是很像绕口令。
#
# 2
# 00:00:08,390 --> 00:00:13,405
# 哎，但你是高中生，高中生可以麻烦，不要有这么多故事嘛，让我们这些成年人很难堪好吗？
#
# 3
# 00:00:14,410 --> 00:00:15,510
# 而且真的很离谱。
#
# 4
# 00:00:16,010 --> 00:00:20,710
# 嗯，也不能说离谱吧，就是很巧啊，就是用很烂的一个梗。
#
# 5
# 00:00:20,730 --> 00:00:24,055
# 就之前有一首很流行的歌叫做哦 verdical incidence。
#
# 6
# 00:00:24,940 --> 00:00:30,680
# 嗯，好来下一条呢就是比较哦浪漫的，就是比较好方向那种离谱了。
#
# 7
# 00:00:31,200 --> 00:00:39,845
# 首先 tornato说高一的时候，因为不在一所学校，离得又比较远，我就拿个老年机和对象半年发了快一千块的短信。
#
#
# 合并字幕完成，开始切分音频
# Slice character_001.wav from 0.0001 to 8.040000000000001
# Slice character_002.wav from 8.290000000000001 to 13.455
# Slice character_004.wav from 15.910000000000002 to 20.72
# Slice character_005.wav from 20.72 to 24.105
# Slice character_006.wav from 24.84 to 30.73
# Slice character_007.wav from 31.099999999999998 to 39.894999999999996

# %% [markdown]
# 后处理 Postprocessing

# %%
# @title 响度标准化 Loudness Normalization
# %cd /content/AudioLabeling
# %pip install tqdm
from tqdm import tqdm

try:
    print(f"source_path: {output_path}")
    source_path = output_path
except:
    source_path = "Output/sliced_audio/test/"
    
target_loudness = -16.0 # 目标响度 @param {type:"number"}
from src.audio_normalizer.my_utils import normalize_loudness

audio_list = scan_audios_walk(source_path)
for audio_file in tqdm(audio_list):
    audio_file_full_path = os.path.join(source_path, audio_file)
    try:
        normalize_loudness(audio_file_full_path, target_loudness=target_loudness, target_path=audio_file_full_path)
    except Exception as e:
        print(f"标准化音频文件失败：{audio_file_full_path}")
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/AudioLabeling'
# e:\AItools\AudioLabeling
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: tqdm in e:\aitools\audiolabeling\runtime\lib\site-packages (4.66.2)
# Requirement already satisfied: colorama in e:\aitools\audiolabeling\runtime\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# source_path: Output/sliced_audio/test_audio/
#   0%|          | 0/79 [00:00<?, ?it/s]e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
#   9%|▉         | 7/79 [00:00<00:01, 56.62it/s]e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
#  28%|██▊       | 22/79 [00:00<00:00, 66.79it/s]e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
#  65%|██████▍   | 51/79 [00:00<00:00, 65.25it/s]e:\AItools\AudioLabeling\runtime\lib\site-packages\pyloudnorm\normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# 100%|██████████| 79/79 [00:01<00:00, 64.11it/s]

# %%
# @title (可选) 进行音频中文情绪分类 (Optional) Chinese Emotion Classification in Audio
# Warning: 当前版本只支持中文音频，并且不会自动重命名list文件中的音频文件名，谨慎使用
# Warning: 基于emotion2vec实现，效果不一定准（对于唱歌素材一定不准）
# %cd /content/AudioLabeling
from src.emotion_recognition.audio2emotion import Audio2Emotion

try :
    print(f"models_path: {models_path}")
except:
    models_path = ""
    
try:
    print(f"source_path: {output_path}")
    source_path = output_path
except:
    source_path = "Output/sliced_audio/test/"

audio_list = scan_audios_walk(source_path)
with Audio2Emotion(models_path=models_path) as a2e:
    for audio_file in audio_list:
        audio_file_full_path = os.path.join(source_path, audio_file)
        emotion = a2e.get_emotion(audio_file_full_path)
        emotion = emotion.split('/')[0]
        filename = os.path.basename(audio_file).rsplit('.', 1)[0]
        new_filename = f"{emotion}#{filename}"
        new_file_full_path = os.path.join(os.path.dirname(audio_file_full_path), f"{new_filename}.{audio_file.rsplit('.', 1)[1]}")
        os.rename(audio_file_full_path, new_file_full_path)

# %% [markdown]
# 打包并下载 Pack and Download

# %%
# @title 打包成zip文件 Zip to a zip file
# %cd /content/AudioLabeling
try:
    print(f"source_path: {output_path}")
    source_path = output_path
except:
    source_path = "Output/sliced_audio/test/"
    
# %pip install zipfile
import zipfile
import os

if source_path.endswith('/'):
    source_path = source_path[:-1]

import time
file_name = os.path.basename(source_path) + f"_{time.strftime('%Y%m%d%H%M%S')}"
dir_path = os.path.dirname(source_path)
zip_file_path = os.path.join(dir_path, f"{file_name}.zip")

with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    for root, _, files in os.walk(source_path):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, file_path.replace(source_path, ''))
    print(f"打包完成：{zip_file_path}")
